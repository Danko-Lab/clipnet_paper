# %%
import numpy as np
import seaborn as sns
from matplotlib.colors import LogNorm, Normalize
from matplotlib.ticker import MaxNLocator

# %%
dfim = np.load(
    "/Users/adamhe/github/scratch/dfim/dfim_profile_EH38E3485200.npz"
)["arr_0"]

sns.heatmap(
    dfim,
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10,
    norm=Normalize(vmin=0, vmax=1e-5),
)
# Out:
# <Axes: >

# %%
dfim = np.load(
    "/Users/adamhe/github/scratch/dfim/dfim_profile_rpl10a.npz"
)["arr_0"]

sns.heatmap(
    dfim,
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10,
    norm=Normalize(vmin=0, vmax=1e-5),
)
# Out:
# <Axes: >

# %%
dfim = np.load(
    "/Users/adamhe/github/scratch/dfim/dfim_quantity_irf7.npz"
)["arr_0"]

sns.heatmap(
    dfim,
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10,
    #norm=Normalize(vmin=0, vmax=1e-5),
)
# Out:
# <Axes: >

# %%
dfim = np.load(
    "/Users/adamhe/github/scratch/dfim/dfim_quantity_rpl10a.npz"
)["arr_0"]

sns.heatmap(
    dfim,
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10,
    norm=Normalize(vmin=0, vmax=0.5),
)
# Out:
# <Axes: >

# %%
dfim = np.load(
    "/Users/adamhe/github/scratch/dfim/dfim_quantity_rpl35.npz"
)["arr_0"]

sns.heatmap(
    dfim,
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10,
    norm=Normalize(vmin=0, vmax=0.3),
)
# Out:
# <Axes: >
