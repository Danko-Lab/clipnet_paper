# %%
import numpy as np
import seaborn as sns
from matplotlib.colors import LogNorm, Normalize
from matplotlib.ticker import MaxNLocator

# %%
dfim=np.load("/Users/adamhe/github/scratch/dfim/dfim_profile_rs8050061.npz")["arr_0"]

# %%
dfim.shape
# Out:
# (100, 100)

# %%
sns.heatmap(
    dfim,
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10,
    #norm=LogNorm(vmax=1, vmin=0),
)
# Out:
# <Axes: >
