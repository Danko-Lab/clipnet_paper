# %%
import numpy as np
import seaborn as sns
from matplotlib.colors import LogNorm, Normalize
from matplotlib.ticker import MaxNLocator

# %%
dfim_profile=np.load("/Users/adamhe/github/scratch/dfim/sp1_tss_windows_reference_seq_dfim_profile.npz")
dfim_profile=np.array([dfim_profile[f] for f in dfim_profile.files])

dfim_quantity=np.load("/Users/adamhe/github/scratch/dfim/sp1_tss_windows_reference_seq_dfim_quantity.npz")
dfim_quantity=np.array([dfim_quantity[f] for f in dfim_quantity.files])

# %%
sns.heatmap(
    dfim_quantity.mean(axis=0),
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10
)
# Out:
# <Axes: >

# %%
sns.heatmap(
    dfim_profile.mean(axis=0).transpose().clip(min=np.percentile(dfim_profile, 0.01), max=np.percentile(dfim_profile, 99.99)),
    cmap="rocket_r",
    xticklabels=10, 
    yticklabels=10,
)
# Out:
# <Axes: >
