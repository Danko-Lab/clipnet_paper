# %%
import numpy as np
import os
import matplotlib.pyplot as plt
np.random.seed(1)

# %%
server="cbsu"
path="/home2/ayh8/attribution_scores/examples"
fp="folds_examples_profile.npz"
scratch="/Users/adamhe/github/scratch"

print(f"scp {server}:{os.path.join(path, fp)} {scratch}")
# Out:
# scp cbsu:/home2/ayh8/attribution_scores/examples/folds_examples_profile.npz /Users/adamhe/github/scratch

# %%
ensemble_deepshap = np.load(os.path.join(scratch, fp))

# %%
mean_shap = np.array([ensemble_deepshap[fold] for fold in ensemble_deepshap.files]).mean(axis=0)

# %%
plot_weights(mean_shap[1, :, 250:750], subticks_frequency=50, neg_height=-5e-6, pos_height=6e-6)
#plt.savefig("ensemble_deepshap_nasp_prom.pdf")

# %%
plot_weights(mean_shap[1, :, 250+210:250+210+15], subticks_frequency=50, neg_height=-1e-5, pos_height=4e-5)
plt.savefig("ensemble_deepshap_nasp_prom_0.pdf")

# %%
plot_weights(mean_shap[1, :, 250+227:250+227+15], subticks_frequency=50, neg_height=-1e-5, pos_height=4e-5)
plt.savefig("ensemble_deepshap_nasp_prom_1.pdf")

# %%
plot_weights(mean_shap[1, :, 250+250:250+250+15], subticks_frequency=50, neg_height=-1e-5, pos_height=4e-5)
plt.savefig("ensemble_deepshap_nasp_prom_2.pdf")

# %%
plot_weights(mean_shap[1, :, 250+280:250+280+15], subticks_frequency=50, neg_height=-1e-5, pos_height=4e-5)
plt.savefig("ensemble_deepshap_nasp_prom_3.pdf")

# %%
plot_weights(mean_shap[46, :, 250:750], subticks_frequency=50, neg_height=-5e-6, pos_height=1.5e-5)
plt.savefig("ensemble_deepshap_EH38E3485200_enh.pdf")

# %%
plot_weights(mean_shap[46, :, 250+205:250+205+15], subticks_frequency=50, neg_height=-5e-6, pos_height=1.5e-5)
plt.savefig("ensemble_deepshap_EH38E3485200_enh_0.pdf")

# %%
plot_weights(mean_shap[46, :, 250+274:250+274+15], subticks_frequency=50, neg_height=-5e-6, pos_height=1.5e-5)
plt.savefig("ensemble_deepshap_EH38E3485200_enh_1.pdf")

# %%
plot_weights(mean_shap[46, :, 250+310:250+310+15], subticks_frequency=50, neg_height=-5e-6, pos_height=1.5e-5)
plt.savefig("ensemble_deepshap_EH38E3485200_enh_2.pdf")

# %%
plot_weights(mean_shap[46, :, 250+333:250+333+15], subticks_frequency=50, neg_height=-5e-6, pos_height=1.5e-5)
plt.savefig("ensemble_deepshap_EH38E3485200_enh_3.pdf")

# %%
plot_weights(mean_shap[54, :, 250:750], subticks_frequency=50, neg_height=-1.1e-5, pos_height=5.5e-5)
plt.savefig("ensemble_deepshap_rpl10a_prom.pdf")

# %%
plot_weights(mean_shap[54, :, 250+273:250+273+15], subticks_frequency=50, neg_height=-1.1e-5, pos_height=5.5e-5)
plt.savefig("ensemble_deepshap_rpl10a_prom_0.pdf")

# %%
plot_weights(mean_shap[54, :, 250+293:250+293+17], subticks_frequency=50, neg_height=-1.1e-5, pos_height=5.5e-5)
plt.savefig("ensemble_deepshap_rpl10a_prom_1.pdf")

# %%
plot_weights(mean_shap[54, :, 250+320:250+320+17], subticks_frequency=50, neg_height=-1.1e-5, pos_height=5.5e-5)
plt.savefig("ensemble_deepshap_rpl10a_prom_2.pdf")

# %%
plot_weights(mean_shap[61, :, 250:750], subticks_frequency=50, neg_height=-2.4e-6, pos_height=6e-6)
plt.savefig("ensemble_deepshap_rpl35_prom.pdf")

# %%
plot_weights(mean_shap[61, :, 250+216:250+216+15][::-1, ::-1], subticks_frequency=50, neg_height=-2.4e-6, pos_height=6e-6)
plt.savefig("ensemble_deepshap_rpl35_prom_0.pdf")

# %%
plot_weights(mean_shap[61, :, 250+233:250+233+15], subticks_frequency=50, neg_height=-2.4e-6, pos_height=6e-6)
plt.savefig("ensemble_deepshap_rpl35_prom_1.pdf")

# %%
plot_weights(mean_shap[61, :, 250+273:250+273+15], subticks_frequency=50, neg_height=-2.4e-6, pos_height=6e-6)
plt.savefig("ensemble_deepshap_rpl35_prom_2.pdf")

# %%
plot_weights(mean_shap[61, :, 250+397:250+397+15], subticks_frequency=50, neg_height=-2.4e-6, pos_height=6e-6)
plt.savefig("ensemble_deepshap_rpl35_prom_4.pdf")

# %%
viz_sequence.plot_weights(mean_shap[50, :, 250:750], subticks_frequency=50)

# %%
viz_sequence.plot_weights(mean_shap[38, :, 250:750], subticks_frequency=50)

# %%
viz_sequence.plot_weights(mean_shap[36, :, 250:750], subticks_frequency=50)

# %%
viz_sequence.plot_weights(mean_shap[39, :, 250:750], subticks_frequency=50)

# %%
viz_sequence.plot_weights(mean_shap[51, :, 250:750], subticks_frequency=50)

# %%
viz_sequence.plot_weights(mean_shap[19, :, 250:750], subticks_frequency=50)

# %%
plot_weights(mean_shap[2, :, 250:750], subticks_frequency=50, neg_height=-4e-5, pos_height=1.6e-4)
plt.savefig("ensemble_deepshap_irf7_prom.pdf")

# %%
start_pos = 190
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5,
    pos_height=1.6e-4
)
plt.savefig("ensemble_deepshap_irf7_prom0.pdf")

# %%
start_pos = 215
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5,
    pos_height=1.6e-4
)
plt.savefig("ensemble_deepshap_irf7_prom1.pdf")

# %%
start_pos = 238
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5,
    pos_height=1.6e-4
)
plt.savefig("ensemble_deepshap_irf7_prom2.pdf")

# %%
start_pos = 274
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5,
    pos_height=1.6e-4
)
plt.savefig("ensemble_deepshap_irf7_prom3.pdf")

# %%
start_pos = 297
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5,
    pos_height=1.6e-4
)
plt.savefig("ensemble_deepshap_irf7_prom4.pdf")

# %%
plot_weights(mean_shap[11, :, 250:750], subticks_frequency=50, neg_height=-1e-5, pos_height=1e-5)

# %%
plot_weights(mean_shap[32, :, 250:500][::-1, ::-1], subticks_frequency=50, neg_height=-6e-6, pos_height=1.8e-5)
