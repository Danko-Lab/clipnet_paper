# %%
"""
This notebook plots DeepSHAP profile tracks used in Fig. 2A-B, Supp. Fig. 2A-B.
"""
# Out:
# '\nThis notebook plots DeepSHAP profile tracks used in Fig. 2A-B, Supp. Fig. 2A-B.\n'

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import sys
sys.path.append("../")
from utils import plot_weights

# %%
# PRINT COMMANDS TO DOWNLOAD AND EXTRACT DATA

# Set SCRATCH to where you want to download data to
SCRATCH = "/Users/adamhe/github/scratch"

URL = "https://zenodo.org/records/10597358/files"
TAR = "example_tracks_and_deepshap.tar.gz"
print(f"wget {URL}/{TAR} -P {SCRATCH}")
print(f"tar -xvzf {SCRATCH}/{TAR} -C {SCRATCH}")
# Out:
# wget https://zenodo.org/records/10597358/files/example_tracks_and_deepshap.tar.gz -P /Users/adamhe/github/scratch
# tar -xvzf /Users/adamhe/github/scratch/example_tracks_and_deepshap.tar.gz -C /Users/adamhe/github/scratch

# %%
# Load data

# SHAP scores
shap = np.load(
    os.path.join(SCRATCH, "example_tracks_and_deepshap/folds_examples_profile.npz")
)
mean_shap = np.array([shap[fold] for fold in shap.files]).mean(axis=0) * 500

# %%
plot_weights(mean_shap[2, :, 250:750], subticks_frequency=50, neg_height=-4e-5*500, pos_height=1.6e-4*500)
plt.savefig("img/ensemble_deepshap_profile_irf7_prom.pdf")

# %%
start_pos = 190
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-2e-5 * 500,
    pos_height=1.6e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf7_prom0.pdf")

# %%
start_pos = 215
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5 * 500,
    pos_height=1.6e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf7_prom1.pdf")

# %%
start_pos = 238
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5 * 500,
    pos_height=1.6e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf7_prom2.pdf")

# %%
start_pos = 274
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5 * 500,
    pos_height=1.6e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf7_prom3.pdf")

# %%
start_pos = 297
plot_weights(
    mean_shap[2, :, 250 + start_pos: 250 + start_pos + 15][::-1, ::-1],
    subticks_frequency=50,
    neg_height=-4e-5 * 500,
    pos_height=1.6e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf7_prom4.pdf")

# %%
plot_weights(mean_shap[48, :, 250:750], subticks_frequency=50, neg_height=-5e-6 * 500, pos_height=1.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_EH38E3485200_enh.pdf")

# %%
plot_weights(mean_shap[48, :, 250+205:250+205+15], subticks_frequency=50, neg_height=-5e-6 * 500, pos_height=1.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_EH38E3485200_enh_3.pdf")

# %%
plot_weights(mean_shap[48, :, 250+274:250+274+15], subticks_frequency=50, neg_height=-5e-6 * 500, pos_height=1.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_EH38E3485200_enh_2.pdf")

# %%
plot_weights(mean_shap[48, :, 250+310:250+310+15], subticks_frequency=50, neg_height=-5e-6 * 500, pos_height=1.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_EH38E3485200_enh_1.pdf")

# %%
plot_weights(mean_shap[48, :, 250+333:250+333+15], subticks_frequency=50, neg_height=-5e-6 * 500, pos_height=1.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_EH38E3485200_enh_0.pdf")

# %%
plot_weights(mean_shap[56, :, 250:750], subticks_frequency=50, neg_height=-1.1e-5 * 500, pos_height=5.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl10a_prom.pdf")

# %%
plot_weights(mean_shap[56, :, 250+273:250+273+15], subticks_frequency=50, neg_height=-1.1e-5 * 500, pos_height=5.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl10a_prom_2.pdf")

# %%
plot_weights(mean_shap[56, :, 250+293:250+293+17], subticks_frequency=50, neg_height=-1.1e-5 * 500, pos_height=5.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl10a_prom_1.pdf")

# %%
plot_weights(mean_shap[56, :, 250+320:250+320+17], subticks_frequency=50, neg_height=-1.1e-5 * 500, pos_height=5.5e-5 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl10a_prom_0.pdf")

# %%
plot_weights(mean_shap[63, :, 250:750], subticks_frequency=50, neg_height=-2.4e-6 * 500, pos_height=6e-6 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl35_prom.pdf")

# %%
plot_weights(mean_shap[63, :, 250+216:250+216+15][::-1, ::-1], subticks_frequency=50, neg_height=-2.4e-6 * 500, pos_height=6e-6 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl35_prom_0.pdf")

# %%
plot_weights(mean_shap[63, :, 250+233:250+233+15], subticks_frequency=50, neg_height=-2.4e-6 * 500, pos_height=6e-6 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl35_prom_1.pdf")

# %%
plot_weights(mean_shap[63, :, 250+273:250+273+15], subticks_frequency=50, neg_height=-2.4e-6 * 500, pos_height=6e-6 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl35_prom_2.pdf")

# %%
plot_weights(mean_shap[63, :, 250+397:250+397+15], subticks_frequency=50, neg_height=-2.4e-6 * 500, pos_height=6e-6 * 500)
plt.savefig("img/ensemble_deepshap_profile_rpl35_prom_4.pdf")
