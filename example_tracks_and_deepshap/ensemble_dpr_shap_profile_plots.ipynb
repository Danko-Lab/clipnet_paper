# %%
"""
This notebook plots DeepSHAP profile tracks for the DPR examples (Fig. 6C-D).
"""
# Out:
# '\nThis notebook plots DeepSHAP profile tracks for the DPR examples (Fig. 6C-D).\n'

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
import sys
sys.path.append("../")
from utils import plot_weights

# %%
# PRINT COMMANDS TO DOWNLOAD AND EXTRACT DATA

# Set SCRATCH to where you want to download data to
SCRATCH = "/Users/adamhe/github/scratch"

URL = "https://zenodo.org/records/10597358/files"
TAR = "example_tracks_and_deepshap.tar.gz"
print(f"wget {URL}/{TAR} -P {SCRATCH}")
print(f"tar -xvzf {SCRATCH}/{TAR} -C {SCRATCH}")
# Out:
# wget https://zenodo.org/records/10597358/files/example_tracks_and_deepshap.tar.gz -P /Users/adamhe/github/scratch
# tar -xvzf /Users/adamhe/github/scratch/example_tracks_and_deepshap.tar.gz -C /Users/adamhe/github/scratch

# %%
# Load data

# SHAP scores
ensemble_shap = np.load(
    os.path.join(SCRATCH, "example_tracks_and_deepshap/mean_across_folds_dpr_profile.npz")
)["arr_0"] * 500

# DPR scores (From the HARPE SVR-H model)
dpr_scores = pd.read_csv(
    os.path.join(SCRATCH, "example_tracks_and_deepshap/active_dpr_svrh.bed.gz"), sep="\t", header=None
)
dpr_desc = dpr_scores.loc[:,10].sort_values(ascending=False).index

# %%
plot_weights(
    ensemble_shap[dpr_desc[1], :, 250:750],
    subticks_frequency=50, neg_height=-1e-4 * 500, pos_height=8e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf1_prom.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[1], :, 250+212:250+212+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-4e-5 * 500, pos_height=1e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf1_prom1.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[1], :, 250+240:250+240+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-2.4e-4 * 500, pos_height=6e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_irf1_prom0.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[5], :, 250:750],
    subticks_frequency=50, neg_height=-3e-5 * 500, pos_height=2.4e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_ivns1abp_prom.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[5], :, 250+212:250+212+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-1.2e-5 * 500, pos_height=6e-5 * 500
)
plt.savefig("img/ensemble_deepshap_profile_ivns1abp_prom1.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[5], :, 250+240:250+240+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-4.8e-5 * 500, pos_height=2.4e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_ivns1abp_prom0.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[6], :, 250:750][::-1, ::-1],
    subticks_frequency=50, neg_height=-3e-5 * 500, pos_height=2.4e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_nolc1_prom.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[6], :, 250+214:250+214+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-1.2e-5 * 500, pos_height=6e-5 * 500
)
plt.savefig("img/ensemble_deepshap_profile_nolc1_prom1.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[6], :, 250+240:250+240+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-4.8e-5 * 500, pos_height=2.4e-4 * 500
)
plt.savefig("img/ensemble_deepshap_profile_nolc1_prom0.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[10], :, 250:750],
    subticks_frequency=50, neg_height=-1e-6 * 500, pos_height=8e-6 * 500
)
plt.savefig("img/ensemble_deepshap_profile_cox6c_prom.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[10], :, 250+212:250+212+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-6e-7 * 500, pos_height=3e-6 * 500
)
plt.savefig("img/ensemble_deepshap_profile_cox6c_prom2.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[10], :, 250+241:250+241+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-1.2e-6 * 500, pos_height=6e-6 * 500
)
plt.savefig("img/ensemble_deepshap_profile_cox6c_prom1.pdf")

# %%
plot_weights(
    ensemble_shap[dpr_desc[10], :, 250+260:250+260+20][::-1, ::-1],
    subticks_frequency=50, neg_height=-1.2e-6 * 500, pos_height=6e-6 * 500
)
plt.savefig("img/ensemble_deepshap_profile_cox6c_prom0.pdf")
