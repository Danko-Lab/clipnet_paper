# %%
"""
This notebook plots the positions of TF-MoDISco profile motifs relative to the TSS.
We mostly use this to identify the distribution of activator motifs around TSS (Fig. 5A).
"""

# %%
import h5py
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
# PRINT COMMANDS TO DOWNLOAD AND EXTRACT DATA

# Set SCRATCH to where you want to download data to
SCRATCH = "/Users/adamhe/github/scratch"

URL = "https://zenodo.org/records/10597358/files"
TAR = "tfmodisco_results.tar.gz"
print(f"wget {URL}/{TAR} -P {SCRATCH}")
print(f"tar -cvzf {SCRATCH}/{TAR}")
# Out:
# wget https://zenodo.org/records/10597358/files/tfmodisco_results.tar.gz -P /Users/adamhe/github/scratch
# tar -cvzf /Users/adamhe/github/scratch/tfmodisco_results.tar.gz

# %%
# Load data

hf = h5py.File(os.path.join(SCRATCH, "tfmodisco_results/mean_across_folds_all_modisco_positions.h5"))
pos = hf["quantity_modisco_positions"]["pos"]
neg = hf["quantity_modisco_positions"]["neg"]

# Set xticks
xticks = [-200, -100, -50, 0, 50, 100, 200]

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 2000
i = 0
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/ETS_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 1000
i = 1
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/SP_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 2
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/NFY_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 3
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/NRF1_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 4
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/YY1_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 5
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/CREB_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 1000
i = 6
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/CA_T_Inr_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 7
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/IRF_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 9
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/CTCF_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 1000
i = 10
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/CA_A_Inr_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 11
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/Arntl_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 100
i = 14
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/THAP_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 16
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/TATA_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 100
i = 17
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/ZBTB33_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 100
i = 27
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_quantity_modisco_position/TATA27_hist.pdf", bbox_inches="tight")
