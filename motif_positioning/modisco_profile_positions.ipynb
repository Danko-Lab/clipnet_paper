# %%
"""
This notebook plots the positions of TF-MoDISco profile motifs relative to the TSS.
We mostly use this to identify the locations of DPR motifs (Fig. 6B).
"""
# Out:
# '\nThis notebook plots the positions of TF-MoDISco profile motifs relative to the TSS.\nWe mostly use this to identify the locations of DPR motifs (Fig. 6B).\n'

# %%
import h5py
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
# PRINT COMMANDS TO DOWNLOAD AND EXTRACT DATA

# Set SCRATCH to where you want to download data to
SCRATCH = "/Users/adamhe/github/scratch"

URL = "https://zenodo.org/records/10597358/files"
TAR = "tfmodisco_results.tar.gz"
print(f"wget {URL}/{TAR} -P {SCRATCH}")
print(f"tar -xvzf {SCRATCH}/{TAR}")
# Out:
# wget https://zenodo.org/records/10597358/files/tfmodisco_results.tar.gz -P /Users/adamhe/github/scratch
# tar -xvzf /Users/adamhe/github/scratch/tfmodisco_results.tar.gz

# %%
# Load data

hf = h5py.File(os.path.join(SCRATCH, "tfmodisco_results/mean_across_folds_all_modisco_positions.h5"))
pos = hf["profile_modisco_positions"]["pos"]
neg = hf["profile_modisco_positions"]["neg"]

# Set xticks
xticks = [-200, -100, -50, 0, 50, 100, 200]

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 10000
i = 0
sns.kdeplot(pos[str(i)][:], bw_adjust=0.5)#, binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
#plt.savefig("img_profile_modisco_position/CA_Inr_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 1000
i = 1
sns.kdeplot(pos[str(i)][:], bw_adjust=0.5)#, binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
#plt.savefig("img_profile_modisco_position/SP_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 2000
i = 2
sns.kdeplot(pos[str(i)][:], bw_adjust=0.5)#, binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
#plt.savefig("img_profile_modisco_position/TATA_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 2000
i = 3
sns.kdeplot(pos[str(i)][:], bw_adjust=0.5)#, binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
#plt.savefig("img_profile_modisco_position/TA_Inr_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 4
sns.kdeplot(pos[str(i)][:], bw_adjust=0.5)#, binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
#plt.savefig("img_profile_modisco_position/ETS_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 2000
i = 5
sns.kdeplot(pos[str(i)][:], bw_adjust=0.5)#, binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
#plt.savefig("img_profile_modisco_position/DPR5_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 6
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/NFY_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 7
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/DPR7_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 1000
i = 8
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/DPR8_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 1000
i = 9
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/DPR9_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 1000
i = 10
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/DPR10_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 11
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/DPR11_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 100
i = 12
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/IRF_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 250
i = 13
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/DPR13_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 14
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/TATA14_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 15
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/CREB_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 100
i = 16
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/NRF1_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 17
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/YY1_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 500
i = 18
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/TGT_Inr_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 200
i = 20
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/POU2F3_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 100
i = 21
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/TFEC_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 25
i = 38
sns.histplot(pos[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/TCT_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 25
i = 0
sns.histplot(neg[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/neg_ETS_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 50
i = 1
sns.histplot(neg[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/neg_SP_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 50
i = 3
sns.histplot(neg[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/neg_YY1_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 20
i = 4
sns.histplot(neg[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/neg_NRF1_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 20
i = 7
sns.histplot(neg[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/neg_NFY_hist.pdf", bbox_inches="tight")

# %%
plt.rcParams["figure.figsize"] = 5,1
fig, (ax) = plt.subplots(nrows = 1, sharex = True)

# 20
i = 15
sns.histplot(neg[str(i)][:], binwidth=10)
ax.set_xlim(-250, 250)
ax.set_xticks(xticks)
plt.savefig("img_profile_modisco_position/neg_CA_Inr_hist.pdf", bbox_inches="tight")
